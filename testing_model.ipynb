# %%
import pandas as pd
df=pd.read_csv("Reviews.csv")
df.head()
# Out:
#     Id   ProductId          UserId                      ProfileName  \
# 0  1.0  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1  2.0  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2  3.0  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3  4.0  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4  5.0  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score          Time  \
# 0                   1.0                     1.0    5.0  1.303862e+09
# 1                   0.0                     0.0    1.0  1.346976e+09
# 2                   1.0                     1.0    4.0  1.219018e+09
# 3                   3.0                     3.0    2.0  1.307923e+09
# 4                   0.0                     0.0    5.0  1.350778e+09
#
#                  Summary                                               Text
# ...

# %%
Id=[]
ProductId=[]
UserId=[]
ProfileName=[]
HelpfulnessNumerator=[]
Score=[]
Time=[]
Summary=[]
Text=[]
count=0
for i in range(50000,80000):
    if df['Score'][i] < 3:
        #Id.append(df['Id'][i])
        ProductId.append(df['ProductId'][i])
        UserId.append(df['UserId'][i])
        ProfileName.append(df['ProfileName'][i])
        HelpfulnessNumerator.append(df['HelpfulnessNumerator'][i])
        Score.append('0')
        Time.append(df['Time'][i])
        Summary.append(df['Summary'][i])
        Text.append(df['Text'][i].lower())
        count+=1
        if count==500:
            break
for i in range(50000,80000):
        if df['Score'][i] >= 3:
        #Id.append(df['Id'][i])
            ProductId.append(df['ProductId'][i])
            UserId.append(df['UserId'][i])
            ProfileName.append(df['ProfileName'][i])
            HelpfulnessNumerator.append(df['HelpfulnessNumerator'][i])
            Score.append('1')
            Time.append(df['Time'][i])
            Summary.append(df['Summary'][i])
            Text.append(df['Text'][i].lower())
            count+=1
            if count==1000:
                break

# %%
df = pd.DataFrame({'ProductId': ProductId, 'UserId': UserId, 'ProfileName': ProfileName, 'HelpfulnessNumerator': HelpfulnessNumerator, 'Score':Score, 'Time':Time, 'Summary':Summary,'Text':Text })
df.to_csv('test.csv',index=False)

# %%
df=pd.read_csv('test.csv')
df.head()
# Out:
#     ProductId          UserId                        ProfileName  \
# 0  B00430B73W  A2PNOU7NXB1JE4                     Peggy "pab920"
# 1  B0019EY7KA  A1V44WCLV1CVIV                           C. RAMOS
# 2  B001D3PY0E  A27NAHUZXN2UAQ                          C. Duncan
# 3  B000E5C234    ACYR6O588USK  '  Groovin' guy "music historian"
# 4  B000ER5DFQ  A1UTKYFGM2ITLU                          B. Citron
#
#    HelpfulnessNumerator  Score          Time  \
# 0                  16.0      0  1.152662e+09
# 1                   0.0      0  1.334275e+09
# 2                   1.0      0  1.335917e+09
# 3                   6.0      0  1.202861e+09
# 4                   1.0      0  1.321142e+09
#
#                                        Summary  \
# 0  Little coconut, lots of dates, minimal nuts
# 1            Quality suffering. Cracks abound.
# 2                               Terrible Taste
# 3                               Too Artificial
# 4                         Plastic in the food!
#
# ...

# %%
len(Summary)
# Out:
# 1000
